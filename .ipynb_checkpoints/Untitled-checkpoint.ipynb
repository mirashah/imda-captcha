# %%
# Analysis of colours
img = Image.open('./input/input00.jpg')
img_array = ["#" if x[0] < 139 else " " for x in list(img.getdata())]

# %%
transformed_img = img.convert("P")
his = transformed_img.histogram()

values = {}

for i in range(256):
    values[i] = his[i]

for col,count in sorted(values.items(), key=itemgetter(1), reverse=True)[:10]:
    print (col,count)
# Out:
# 225 1175
# 182 189
# 0 169
# 139 138
# 189 39
# 224 23
# 219 21
# 175 17
# 140 7
# 218 7

# %%
x = np.reshape(img_array, (30, 60)).transpose().tolist()
# Out:
# [[' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' '],
#  [' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' '],
#  [' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' '],
#  [' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
# ...

# %%
blank_col = [" "] * 30
split_captcha = []
char = []
for col in x:
    if col == blank_col and len(char) == 0:
        continue
    elif col == blank_col and len(char) != 0:
        # end of letter
        split_captcha.append(char)
        char = []
    else:
        char.append(col)

# %%
len(split_captcha)
# Out:
# 5

# %%
from PIL import Image
import numpy as np

# %%
class Captcha(object):
    def __init__(self):
        self.img_array = []
        self.noise_threshold = 139
        pass

    def __call__(self, im_path, save_path):
        """
        Algo for inference
        args:
            im_path: .jpg image path to load and to infer
            save_path: output file path to save the one-line outcome
        """
        self.load_transformed_img(im_path)
        pass
    
    def load_transformed_img(self, im_path):
        """
        Strips noise from Captcha and stores simplified image in img_array
        """
        img = Image.open(im_path)
        self.img_array = ["#" if x[0] < self.noise_threshold else " " for x in list(img.getdata())]
        return
    
    def split_img(self):
        
    
    def print_img(self):
        line = ''
        count = 0
        for pixel in self.img_array:
            line += pixel
            count += 1
            if count == 60:
                print(line)
                line = ''
                count = 0
        return

# %%
x = Captcha()
x('./input/input00.jpg', None)
x.print_img()
# Out:
#
#
#
#
#
#
#
#
#
#
#
#      #######    #####  ##    ## ##    ##      ##
#      ##        ##   ## ##    ## ##   ##      ###
#      ##       ##        ##  ##  ##  ##      ####
#      ##       ##         ####   ## ##      ## ##
#      ######   ##          ##    ####      ##  ##
#      ##       ##   ###    ##    ####     ##   ##
#      ##       ##    ##    ##    ## ##    ########
#      ##       ##    ##    ##    ##  ##        ##
#      ##        ##   ##    ##    ##   ##       ##
#      #######    #####     ##    ##    ##      ##
